# %%
import nltk
from textblob import TextBlob
import pandas as pd
import numpy as np
from nltk import word_tokenize, sent_tokenize
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.decomposition import NMF
import re
from scipy.spatial.distance import pdist, squareform, cdist
import matplotlib.pyplot as plt
from pattern.en import tag
from sklearn.neighbors import KDTree, NearestNeighbors
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.preprocessing import normalize
import pickle
# %matplotlib inline

# %% [markdown]
# # Load Business TFIDF Matrix and Measure Similarity to Other Businesses

# %%
def cos_cdist(matrix, vector):
    """
    Compute the cosine distances between each row of a matrix and vector.
    """
    v = vector.reshape(1, -1)
    return cdist(matrix, v, 'cosine').reshape(-1)

def get_sim_biz(biz_arr, df_biz, biz_dict, k, biz_name):
    """
    Return a dataframe with the top k matches based on smallest cosine distance between a business
    vector and an array of features for other businesses
    biz_arr: can be tfidf matrix or topic model features for each business
    df_biz: a dataframe with additional business data like name, overview, etc.
    biz_dict: a dictionary that serves as a crosswalk between a business name and its index in the feature array
    k: the number of closest results to return as matches for a business
    biz_name: the name of the business to serve as the basis for finding similar businesses
    """
    cosine_distance = cos_cdist(biz_arr, biz_arr[biz_dict[biz_name]])
    indices = np.argsort(cosine_distance)[:k]
    distance = cosine_distance[indices]
    df = pd.DataFrame(distance, index=indices, columns=['distance'])
    df_nn = df_biz.merge(df, left_index = True, right_index = True)
    return df_nn

# %%
#Load business data for those that have overview text >30 characters, are in a US State
#and are identified as a 'Company'
biz = pd.read_csv(
    '/Users/sarah/ds/metis/projects/kojak/USCompanyOverviewDataState.csv', encoding = 'latin-1')
#Load the business TFIDF matrix
biztfidf_arr = pickle.load(open("/Users/sarah/ds/metis/projects/kojak/biztfidf.p", "rb")).toarray()
##Load the NMF business topic matrix
biz_arr = pickle.load(open("/Users/sarah/ds/metis/projects/kojak/biztopic_matrix.p", "rb"))
#Load the the dictionary that maps company names to index values
biz_dict = pickle.load(open("/Users/sarah/ds/metis/projects/kojak/bizname_index_crosswalk.p", "rb"))

# %%
#Run calculation to retrun the most similar companies
get_sim_biz(biztfidf_arr, biz, biz_dict, 15, biz_name = 'FanDuel')
# Out:
#       company_id                    company_name  \
# 24760     c:2640                         FanDuel
# 1339      c:1240                        DraftMix
# 44340     c:6996               Sport Interactiva
# 18649    c:22575                     PaperSports
# 46887    c:78857                         RotoBiz
# 15660    c:19841  Fantazzle Fantasy Sports Games
# 18317    c:22320                BetAgainstMe.com
# 19446   c:231882            Star Fantasy Leagues
# 1448      c:1263                Screaming Sports
# 19741   c:233817          Bignoggins Productions
# 23495   c:257218                         LockApp
# 26191    c:27026         Fantasy Sports Ventures
# 7583    c:162946                      DraftKings
# 33674    c:39881                        RotoWire
# 9811    c:172668                    Wedge Buster
#
#               company_name_normalized  \
# 24760                         fanduel
# 1339                         draftmix
# 44340               sport interactiva
# 18649                     papersports
# 46887                         rotobiz
# 15660  fantazzle fantasy sports games
# 18317                    betagainstme
# 19446            star fantasy leagues
# 1448                 screaming sports
# 19741          bignoggins productions
# 23495                         lockapp
# 26191         fantasy sports ventures
# 7583                       draftkings
# 33674                        rotowire
# 9811                     wedge buster
#
#                                         company_overview      distance
# 24760  FanDuel, launched in July 2009, is now the lea... -2.220446e-16
# 1339   On DraftMix fantasy sports fans can sign up an...  2.496057e-01
# 44340  Creates fantasy sports games for sports like s...  3.070522e-01
# 18649  At PaperSports fantasy sports players can pick...  3.200894e-01
# 46887  RotoBiz covers the business of fantasy sports ...  3.228090e-01
# 15660  Fantazzle provides weekly fantasy sports games...  3.276019e-01
# 18317  BetAgainstMe.com is a fantasy sports betting w...  3.310632e-01
# 19446  Star Fantasy Leagues provides a daily, weekly,...  3.429680e-01
# 1448   Screaming Sports is a social networking servic...  3.432409e-01
# 19741  Bignoggins Productions was founded by Jerry Sh...  3.512864e-01
# 23495  Lock is a mobile fantasy sports application th...  3.602166e-01
# 26191  Fantasy Sports Ventures, Inc. operates fantasy...  3.617413e-01
# 7583   DraftKings is a daily fantasy sports website w...  3.661337e-01
# 33674  RotoWire.com is the leading fantasy sports res...  4.059979e-01
# 9811   Wedge Buster is on a mission to bring sports g...  4.175660e-01

# %% [markdown]
# # Create Investor Topics and Measure Similarity to Businesses

# %%
def get_sim_entity(entity_arr, biz_arr, df_entity, biz_dict, k, biz_name):
    """
    Return a dataframe with the top k matches based on smallest cosine distance between a business
    vector and an array of the same set of features for investor companies/individuals/other entities
    entity_arr: can be tfidf matrix or topic model features for each entity
    biz_arr: can be tfidf matrix or topic model features for each business
    df_entity: a dataframe with additional entity data like name, overview, etc.
    biz_dict: a dictionary that serves as a crosswalk between a business name and its index in the biz feature array
    k: the number of closest results to return as entity matches for a business
    biz_name: the name of the business to serve as the basis for finding similar entities
    """
    cosine_distance = cos_cdist(entity_arr, biz_arr[biz_dict[biz_name]])
    indices = np.argsort(cosine_distance)[:k]
    distance = cosine_distance[indices]
    df = pd.DataFrame(distance, index=indices, columns=['distance'])
    df_nn = df_entity.merge(df, left_index = True, right_index = True)
    return df_nn

# %% [markdown]
# ## Use Averaging Across Topics to Get Investor Similarity
# Note: for investors - business similarity using scores based on topics as opposed to raw word/n-gram tfidf scores in order to get a more generalized match. The assumption is that you want investors that invest in industries or company types similar to the company of interest as opposed to those who have already made investments in that exact company or very similar companies. Also, given that only ~20% of the companies have a qualifying investor, it seems better to use a more generalized approach here for evaluating similarity.

# %%
#Profile data for the investor candidates. Only investors with 5+ investments in our candidate companies are selected
df_inv_prof = pd.read_csv(
    '/Users/sarah/ds/metis/projects/kojak/InvestorProfileData5Inv.csv', encoding = 'latin-1')
#Crosswalk between businesses and investors, used to pull in business tfidf and/or topic scores to be averaged for each
#investor
inv = pd.read_csv(
    '/Users/sarah/ds/metis/projects/kojak/USCompanyInvestorCrosswalk5Inv.csv', encoding = 'latin-1')

# %%
inv.head()
# Out:
#   investor_id company_id
# 0         f:1     c:1088
# 1         f:1     c:1101
# 2         f:1     c:1102
# 3         f:1    c:11042
# 4         f:1    c:11391

# %%
#Append company topic scores to investors
df_inv = inv.merge(pd.DataFrame(biz['company_id']).join(pd.DataFrame(biz_arr)), on = 'company_id')

# %%
df_inv.head()
# Out:
#   investor_id company_id         0  1         2  3  4         5  6         7  \
# 0         f:1     c:1088  0.029734  0  0.000949  0  0  0.003229  0  0.007803
# 1        f:17     c:1088  0.029734  0  0.000949  0  0  0.003229  0  0.007803
# 2        f:34     c:1088  0.029734  0  0.000949  0  0  0.003229  0  0.007803
# 3        f:45     c:1088  0.029734  0  0.000949  0  0  0.003229  0  0.007803
# 4      f:4689     c:1088  0.029734  0  0.000949  0  0  0.003229  0  0.007803
#
#   ...        190       191  192  193  194  195  196       197      198  199
# 0 ...   0.000006  0.000121    0    0    0    0    0  0.000192  0.01764    0
# 1 ...   0.000006  0.000121    0    0    0    0    0  0.000192  0.01764    0
# 2 ...   0.000006  0.000121    0    0    0    0    0  0.000192  0.01764    0
# 3 ...   0.000006  0.000121    0    0    0    0    0  0.000192  0.01764    0
# 4 ...   0.000006  0.000121    0    0    0    0    0  0.000192  0.01764    0
#
# [5 rows x 202 columns]

# %%
#Average topic scores by investor across all businesses an investor has funded
df_inv_avg = df_inv.groupby('investor_id', as_index = False).mean()

# %%
df_inv_avg.head()
# Out:
#   investor_id         0         1         2         3         4         5  \
# 0         f:1  0.009466  0.001367  0.007716  0.004005  0.000625  0.000566
# 1        f:10  0.007431  0.000849  0.002287  0.005946  0.000370  0.002154
# 2     f:10031  0.003206  0.000656  0.012529  0.010512  0.000020  0.000467
# 3     f:10050  0.002810  0.002517  0.000000  0.000071  0.000014  0.000629
# 4      f:1007  0.006196  0.000106  0.000869  0.009970  0.002614  0.000001
#
#           6             7         8    ...          190       191       192  \
# 0  0.000026  1.698467e-03  0.000278    ...     0.001606  0.000660  0.002595
# 1  0.000004  4.287758e-03  0.000058    ...     0.001059  0.000018  0.001790
# 2  0.000020  9.698595e-06  0.000011    ...     0.003647  0.002306  0.000000
# 3  0.000000  2.600111e-05  0.000000    ...     0.000663  0.000000  0.004937
# 4  0.000032  6.429232e-07  0.002904    ...     0.000411  0.000162  0.000182
#
#         193       194       195       196       197       198       199
# 0  0.000272  0.003327  0.001824  0.000842  0.004356  0.003218  0.001524
# 1  0.001006  0.004873  0.002511  0.000544  0.003217  0.000501  0.000137
# 2  0.000426  0.000211  0.002945  0.000081  0.002332  0.000652  0.000082
# 3  0.000000  0.006947  0.000000  0.000000  0.007888  0.001321  0.000000
# 4  0.000022  0.000018  0.000268  0.002062  0.000149  0.005364  0.000003
#
# [5 rows x 201 columns]

# %%
inv_avg_arr = df_inv_avg.iloc[:,1:].as_matrix()

# %%
#Run calculation to retrun the most similar investors (i.e. investors who have invested in the most similar companies)
get_sim_entity(inv_avg_arr, biz_arr, df_inv_prof, biz_dict, k = 10, biz_name = 'FanDuel')
# Out:
#      investor_id   entity_type            investor_name  \
# 1363      p:3562        Person          Richard Wolpert
# 1488     p:81839        Person       Anonymous Investor
# 8        f:10144  FinancialOrg  Softbank Ventures Korea
# 210       f:1550  FinancialOrg      SK Telecom Ventures
# 1435     p:63410        Person            Paul Bricault
# 1184      f:9558  FinancialOrg  Signia Venture Partners
# 1411     p:53919        Person       Christina Brodbeck
# 1388       p:441        Person                Jarl Mohn
# 208       f:1540  FinancialOrg              TWJ Capital
# 32        f:1056  FinancialOrg      TriplePoint Capital
#
#      investor_name_normalized  \
# 1363          richard wolpert
# 1488       anonymous investor
# 8     softbank ventures korea
# 210       sk telecom ventures
# 1435            paul bricault
# 1184           signia venture
# 1411       christina brodbeck
# 1388                jarl mohn
# 208                       twj
# 32                triplepoint
#
#                                                overview twitter_username  \
# 1363  Richard Wolpert is leading the [new consortium...              NaN
# 1488                                                NaN              NaN
# 8     SoftBank Ventures Korea (SBVK) is a venture ca...    softbankkorea
# 210   SK Telecom Ventures is the investment arm of [...              NaN
# 1435  Paul Bricault is a Venture Partner at Greycrof...        pbricault
# 1184  Signia Venture Partners is an early stage fund...         SigniaVC
# 1411  Christina Brodbeck is an angel investor, user ...              NaN
# 1388  Jarl Mohn brings extensive media experience to...              NaN
# 208   TWJ Capital makes growth equity investments in...              NaN
# 32    TriplePoint Capital offers leases and loans to...              NaN
#
#                          domain        city state_code    region country_code  \
# 1363                        NaN         NaN        NaN   unknown          NaN
# 1488                        NaN         NaN        NaN   unknown          NaN
# 8                softbank.co.kr       Seoul        NaN     Seoul          KOR
# 210                   sktvc.com   Sunnyvale         CA    SF Bay          USA
# 1435                        NaN         NaN        NaN   unknown          NaN
# 1184  signiaventurepartners.com  Menlo Park         CA    SF Bay          USA
# 1411                        NaN         NaN        NaN   unknown          NaN
# 1388                        NaN         NaN        NaN   unknown          NaN
# 208              twjcapital.com    Stamford         CT  New York          USA
# 32       triplepointcapital.com  Menlo Park         CA    SF Bay          USA
#
#       num_investments  comp_investments  distance
# 1363                8                 8  0.153630
# 1488                7                 6  0.168943
# 8                   6                 6  0.171041
# 210                16                11  0.188934
# 1435                6                 5  0.191321
# 1184               25                24  0.195719
# 1411                5                 5  0.197099
# 1388               16                10  0.220651
# 208                 8                 6  0.236844
# 32                 33                30  0.241637

# %%
# Take a look at all the companies each recommended investor has invested in to sanity check similarity
get_sim_entity(inv_avg_arr, biz_arr, df_inv_prof, biz_dict, k =10, biz_name = 'FanDuel').merge(
    inv, on = 'investor_id').merge(biz, on = 'company_id').sort_values(by = 'distance')
# Out:
#     investor_id   entity_type            investor_name  \
# 0        p:3562        Person          Richard Wolpert
# 1        p:3562        Person          Richard Wolpert
# 2        p:3562        Person          Richard Wolpert
# 3        p:3562        Person          Richard Wolpert
# 4        p:3562        Person          Richard Wolpert
# 5        p:3562        Person          Richard Wolpert
# 6        p:3562        Person          Richard Wolpert
# 9        p:3562        Person          Richard Wolpert
# 15      p:81839        Person       Anonymous Investor
# 14      p:81839        Person       Anonymous Investor
# 13      p:81839        Person       Anonymous Investor
# 12      p:81839        Person       Anonymous Investor
# 10      p:81839        Person       Anonymous Investor
# 11      p:81839        Person       Anonymous Investor
# 16      f:10144  FinancialOrg  Softbank Ventures Korea
# 17      f:10144  FinancialOrg  Softbank Ventures Korea
# 18      f:10144  FinancialOrg  Softbank Ventures Korea
# 19      f:10144  FinancialOrg  Softbank Ventures Korea
# 20      f:10144  FinancialOrg  Softbank Ventures Korea
# 21      f:10144  FinancialOrg  Softbank Ventures Korea
# 28       f:1550  FinancialOrg      SK Telecom Ventures
# 32       f:1550  FinancialOrg      SK Telecom Ventures
# 33       f:1550  FinancialOrg      SK Telecom Ventures
# 31       f:1550  FinancialOrg      SK Telecom Ventures
# 29       f:1550  FinancialOrg      SK Telecom Ventures
# 27       f:1550  FinancialOrg      SK Telecom Ventures
# 24       f:1550  FinancialOrg      SK Telecom Ventures
# 25       f:1550  FinancialOrg      SK Telecom Ventures
# 26       f:1550  FinancialOrg      SK Telecom Ventures
# 23       f:1550  FinancialOrg      SK Telecom Ventures
# ..          ...           ...                      ...
# 108      f:1056  FinancialOrg      TriplePoint Capital
# 107      f:1056  FinancialOrg      TriplePoint Capital
# 106      f:1056  FinancialOrg      TriplePoint Capital
# 105      f:1056  FinancialOrg      TriplePoint Capital
# 104      f:1056  FinancialOrg      TriplePoint Capital
# 103      f:1056  FinancialOrg      TriplePoint Capital
# 102      f:1056  FinancialOrg      TriplePoint Capital
# 101      f:1056  FinancialOrg      TriplePoint Capital
# 100      f:1056  FinancialOrg      TriplePoint Capital
# 99       f:1056  FinancialOrg      TriplePoint Capital
# 98       f:1056  FinancialOrg      TriplePoint Capital
# 97       f:1056  FinancialOrg      TriplePoint Capital
# 96       f:1056  FinancialOrg      TriplePoint Capital
# 95       f:1056  FinancialOrg      TriplePoint Capital
# 94       f:1056  FinancialOrg      TriplePoint Capital
# 92       f:1056  FinancialOrg      TriplePoint Capital
# 91       f:1056  FinancialOrg      TriplePoint Capital
# 90       f:1056  FinancialOrg      TriplePoint Capital
# 89       f:1056  FinancialOrg      TriplePoint Capital
# 88       f:1056  FinancialOrg      TriplePoint Capital
# 87       f:1056  FinancialOrg      TriplePoint Capital
# 86       f:1056  FinancialOrg      TriplePoint Capital
# 85       f:1056  FinancialOrg      TriplePoint Capital
# 84       f:1056  FinancialOrg      TriplePoint Capital
# 83       f:1056  FinancialOrg      TriplePoint Capital
# 82       f:1056  FinancialOrg      TriplePoint Capital
# 43       f:1056  FinancialOrg      TriplePoint Capital
# 109      f:1056  FinancialOrg      TriplePoint Capital
# 93       f:1056  FinancialOrg      TriplePoint Capital
# 110      f:1056  FinancialOrg      TriplePoint Capital
#
#     investor_name_normalized  \
# 0            richard wolpert
# 1            richard wolpert
# 2            richard wolpert
# 3            richard wolpert
# 4            richard wolpert
# 5            richard wolpert
# 6            richard wolpert
# 9            richard wolpert
# 15        anonymous investor
# 14        anonymous investor
# 13        anonymous investor
# 12        anonymous investor
# 10        anonymous investor
# 11        anonymous investor
# 16   softbank ventures korea
# 17   softbank ventures korea
# 18   softbank ventures korea
# 19   softbank ventures korea
# 20   softbank ventures korea
# 21   softbank ventures korea
# 28       sk telecom ventures
# 32       sk telecom ventures
# 33       sk telecom ventures
# 31       sk telecom ventures
# 29       sk telecom ventures
# 27       sk telecom ventures
# 24       sk telecom ventures
# 25       sk telecom ventures
# 26       sk telecom ventures
# 23       sk telecom ventures
# ..                       ...
# 108              triplepoint
# 107              triplepoint
# 106              triplepoint
# 105              triplepoint
# 104              triplepoint
# 103              triplepoint
# 102              triplepoint
# 101              triplepoint
# 100              triplepoint
# 99               triplepoint
# 98               triplepoint
# 97               triplepoint
# 96               triplepoint
# 95               triplepoint
# 94               triplepoint
# 92               triplepoint
# 91               triplepoint
# 90               triplepoint
# 89               triplepoint
# 88               triplepoint
# 87               triplepoint
# 86               triplepoint
# 85               triplepoint
# 84               triplepoint
# 83               triplepoint
# 82               triplepoint
# 43               triplepoint
# 109              triplepoint
# 93               triplepoint
# 110              triplepoint
#
#                                               overview twitter_username  \
# 0    Richard Wolpert is leading the [new consortium...              NaN
# 1    Richard Wolpert is leading the [new consortium...              NaN
# 2    Richard Wolpert is leading the [new consortium...              NaN
# 3    Richard Wolpert is leading the [new consortium...              NaN
# 4    Richard Wolpert is leading the [new consortium...              NaN
# 5    Richard Wolpert is leading the [new consortium...              NaN
# 6    Richard Wolpert is leading the [new consortium...              NaN
# 9    Richard Wolpert is leading the [new consortium...              NaN
# 15                                                 NaN              NaN
# 14                                                 NaN              NaN
# 13                                                 NaN              NaN
# 12                                                 NaN              NaN
# 10                                                 NaN              NaN
# 11                                                 NaN              NaN
# 16   SoftBank Ventures Korea (SBVK) is a venture ca...    softbankkorea
# 17   SoftBank Ventures Korea (SBVK) is a venture ca...    softbankkorea
# 18   SoftBank Ventures Korea (SBVK) is a venture ca...    softbankkorea
# 19   SoftBank Ventures Korea (SBVK) is a venture ca...    softbankkorea
# 20   SoftBank Ventures Korea (SBVK) is a venture ca...    softbankkorea
# 21   SoftBank Ventures Korea (SBVK) is a venture ca...    softbankkorea
# 28   SK Telecom Ventures is the investment arm of [...              NaN
# 32   SK Telecom Ventures is the investment arm of [...              NaN
# 33   SK Telecom Ventures is the investment arm of [...              NaN
# 31   SK Telecom Ventures is the investment arm of [...              NaN
# 29   SK Telecom Ventures is the investment arm of [...              NaN
# 27   SK Telecom Ventures is the investment arm of [...              NaN
# 24   SK Telecom Ventures is the investment arm of [...              NaN
# 25   SK Telecom Ventures is the investment arm of [...              NaN
# 26   SK Telecom Ventures is the investment arm of [...              NaN
# 23   SK Telecom Ventures is the investment arm of [...              NaN
# ..                                                 ...              ...
# 108  TriplePoint Capital offers leases and loans to...              NaN
# 107  TriplePoint Capital offers leases and loans to...              NaN
# 106  TriplePoint Capital offers leases and loans to...              NaN
# 105  TriplePoint Capital offers leases and loans to...              NaN
# 104  TriplePoint Capital offers leases and loans to...              NaN
# 103  TriplePoint Capital offers leases and loans to...              NaN
# 102  TriplePoint Capital offers leases and loans to...              NaN
# 101  TriplePoint Capital offers leases and loans to...              NaN
# 100  TriplePoint Capital offers leases and loans to...              NaN
# 99   TriplePoint Capital offers leases and loans to...              NaN
# 98   TriplePoint Capital offers leases and loans to...              NaN
# 97   TriplePoint Capital offers leases and loans to...              NaN
# 96   TriplePoint Capital offers leases and loans to...              NaN
# 95   TriplePoint Capital offers leases and loans to...              NaN
# 94   TriplePoint Capital offers leases and loans to...              NaN
# 92   TriplePoint Capital offers leases and loans to...              NaN
# 91   TriplePoint Capital offers leases and loans to...              NaN
# 90   TriplePoint Capital offers leases and loans to...              NaN
# 89   TriplePoint Capital offers leases and loans to...              NaN
# 88   TriplePoint Capital offers leases and loans to...              NaN
# 87   TriplePoint Capital offers leases and loans to...              NaN
# 86   TriplePoint Capital offers leases and loans to...              NaN
# 85   TriplePoint Capital offers leases and loans to...              NaN
# 84   TriplePoint Capital offers leases and loans to...              NaN
# 83   TriplePoint Capital offers leases and loans to...              NaN
# 82   TriplePoint Capital offers leases and loans to...              NaN
# 43   TriplePoint Capital offers leases and loans to...              NaN
# 109  TriplePoint Capital offers leases and loans to...              NaN
# 93   TriplePoint Capital offers leases and loans to...              NaN
# 110  TriplePoint Capital offers leases and loans to...              NaN
#
#                      domain        city state_code   region country_code  \
# 0                       NaN         NaN        NaN  unknown          NaN
# 1                       NaN         NaN        NaN  unknown          NaN
# 2                       NaN         NaN        NaN  unknown          NaN
# 3                       NaN         NaN        NaN  unknown          NaN
# 4                       NaN         NaN        NaN  unknown          NaN
# 5                       NaN         NaN        NaN  unknown          NaN
# 6                       NaN         NaN        NaN  unknown          NaN
# 9                       NaN         NaN        NaN  unknown          NaN
# 15                      NaN         NaN        NaN  unknown          NaN
# 14                      NaN         NaN        NaN  unknown          NaN
# 13                      NaN         NaN        NaN  unknown          NaN
# 12                      NaN         NaN        NaN  unknown          NaN
# 10                      NaN         NaN        NaN  unknown          NaN
# 11                      NaN         NaN        NaN  unknown          NaN
# 16           softbank.co.kr       Seoul        NaN    Seoul          KOR
# 17           softbank.co.kr       Seoul        NaN    Seoul          KOR
# 18           softbank.co.kr       Seoul        NaN    Seoul          KOR
# 19           softbank.co.kr       Seoul        NaN    Seoul          KOR
# 20           softbank.co.kr       Seoul        NaN    Seoul          KOR
# 21           softbank.co.kr       Seoul        NaN    Seoul          KOR
# 28                sktvc.com   Sunnyvale         CA   SF Bay          USA
# 32                sktvc.com   Sunnyvale         CA   SF Bay          USA
# 33                sktvc.com   Sunnyvale         CA   SF Bay          USA
# 31                sktvc.com   Sunnyvale         CA   SF Bay          USA
# 29                sktvc.com   Sunnyvale         CA   SF Bay          USA
# 27                sktvc.com   Sunnyvale         CA   SF Bay          USA
# 24                sktvc.com   Sunnyvale         CA   SF Bay          USA
# 25                sktvc.com   Sunnyvale         CA   SF Bay          USA
# 26                sktvc.com   Sunnyvale         CA   SF Bay          USA
# 23                sktvc.com   Sunnyvale         CA   SF Bay          USA
# ..                      ...         ...        ...      ...          ...
# 108  triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 107  triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 106  triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 105  triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 104  triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 103  triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 102  triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 101  triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 100  triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 99   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 98   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 97   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 96   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 95   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 94   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 92   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 91   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 90   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 89   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 88   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 87   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 86   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 85   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 84   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 83   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 82   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 43   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 109  triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 93   triplepointcapital.com  Menlo Park         CA   SF Bay          USA
# 110  triplepointcapital.com  Menlo Park         CA   SF Bay          USA
#
#      num_investments  comp_investments  distance company_id  \
# 0                  8                 8  0.153630    c:10252
# 1                  8                 8  0.153630     c:1399
# 2                  8                 8  0.153630   c:163875
# 3                  8                 8  0.153630     c:2553
# 4                  8                 8  0.153630     c:3576
# 5                  8                 8  0.153630      c:453
# 6                  8                 8  0.153630    c:65608
# 9                  8                 8  0.153630     c:8467
# 15                 7                 6  0.168943    c:80400
# 14                 7                 6  0.168943    c:71120
# 13                 7                 6  0.168943    c:67798
# 12                 7                 6  0.168943    c:65169
# 10                 7                 6  0.168943   c:243155
# 11                 7                 6  0.168943   c:247049
# 16                 6                 6  0.171041   c:170703
# 17                 6                 6  0.171041   c:179400
# 18                 6                 6  0.171041   c:233511
# 19                 6                 6  0.171041    c:24873
# 20                 6                 6  0.171041   c:283920
# 21                 6                 6  0.171041    c:72413
# 28                16                11  0.188934    c:49464
# 32                16                11  0.188934    c:69854
# 33                16                11  0.188934      c:933
# 31                16                11  0.188934    c:67086
# 29                16                11  0.188934    c:55476
# 27                16                11  0.188934     c:4832
# 24                16                11  0.188934     c:3487
# 25                16                11  0.188934    c:47011
# 26                16                11  0.188934    c:47115
# 23                16                11  0.188934      c:131
# ..               ...               ...       ...        ...
# 108               33                30  0.241637    c:65893
# 107               33                30  0.241637    c:53885
# 106               33                30  0.241637     c:5208
# 105               33                30  0.241637    c:52072
# 104               33                30  0.241637        c:5
# 103               33                30  0.241637    c:44920
# 102               33                30  0.241637    c:42651
# 101               33                30  0.241637    c:39101
# 100               33                30  0.241637    c:38215
# 99                33                30  0.241637    c:32779
# 98                33                30  0.241637    c:29184
# 97                33                30  0.241637   c:284522
# 96                33                30  0.241637    c:27113
# 95                33                30  0.241637    c:24997
# 94                33                30  0.241637     c:2334
# 92                33                30  0.241637    c:21125
# 91                33                30  0.241637     c:2004
# 90                33                30  0.241637   c:196633
# 89                33                30  0.241637   c:188894
# 88                33                30  0.241637   c:185066
# 87                33                30  0.241637    c:18051
# 86                33                30  0.241637   c:177604
# 85                33                30  0.241637     c:1579
# 84                33                30  0.241637   c:141233
# 83                33                30  0.241637   c:140797
# 82                33                30  0.241637    c:10704
# 43                33                30  0.241637   c:143420
# 109               33                30  0.241637    c:77180
# 93                33                30  0.241637     c:2234
# 110               33                30  0.241637    c:78701
#
#             company_name company_name_normalized  \
# 0                 Mob.ly                  mob ly
# 1             GameLayers              gamelayers
# 2             Tuition.io              tuition io
# 3        EVO Media Group         evo media group
# 4                 Intent                  intent
# 5             Kongregate              kongregate
# 6                Playdek                 playdek
# 9               OGPlanet                ogplanet
# 15        Matatena Games          matatena games
# 14         Triples Media           triples media
# 13          Dynamo Media            dynamo media
# 12             The Lions               the lions
# 10               iQCoPay                 iqcopay
# 11            SLIC games              slic games
# 16                KnowRe                  knowre
# 17        Play Megaphone          play megaphone
# 18               SEWORKS                 seworks
# 19          TVU Networks            tvu networks
# 20              Playnery                playnery
# 21           Enders Fund                  enders
# 28           Argyle Data             argyle data
# 32            Chartboost              chartboost
# 33       Sim Ops Studios         sim ops studios
# 31               Sequent                 sequent
# 29                   Cue                     cue
# 27                 Kabam                   kabam
# 24               Mytopia                 mytopia
# 25          Wild Pockets            wild pockets
# 26                  Giiv                    giiv
# 23               RockYou                 rockyou
# ..                   ...                     ...
# 108            LaunchBit               launchbit
# 107               AdGrok                  adgrok
# 106               Nvidia                  nvidia
# 105              CPUsage                 cpusage
# 104             Facebook                facebook
# 103                Kaiam                   kaiam
# 102               ZipZap                  zipzap
# 101               Gaikai                  gaikai
# 100        Harvest Power           harvest power
# 99          Compass Labs            compass labs
# 98                   Kno                     kno
# 97                Heyday                  heyday
# 96                 Jelli                   jelli
# 95                Virdia                  virdia
# 94                  TiVo                    tivo
# 92        One Kings Lane          one kings lane
# 91         Citrix Online           citrix online
# 90         Emu Messenger           emu messenger
# 89            streamOnce              streamonce
# 88   Enigma Technologies     enigma technologies
# 87             Quick Hit               quick hit
# 86            Playnomics              playnomics
# 85           Gilt Groupe             gilt groupe
# 84          Omada Health            omada health
# 83                Euclid                  euclid
# 82                 Chegg                   chegg
# 43                Rumble                  rumble
# 109        Aquion Energy           aquion energy
# 93               TwoFish                 twofish
# 110             Surf Air                surf air
#
#                                       company_overview
# 0    Mob.ly, formerly Goodrec,  is a mobile and onl...
# 1    GameLayers Inc was a small game design company...
# 2    Tuition.io is a revolutionary new tool for man...
# 3    The EVO Media Group, Inc. ("EVO") is a venture...
# 4    [Intent](http://www.intent.com) is a start-up ...
# 5    Kongregate is a casual gaming social network w...
# 6    Playdek is a mobile portal, developer and plat...
# 9    OGPlanet is an MMO (Massive Multiplayer Online...
# 15   Matatena LLC, based in Houston TX, specializes...
# 14   We are a digital media company that primarily ...
# 13   Dynamo provides media companies, producers and...
# 12   TheLions is an angel-backed startup in San Fra...
# 10   iQCoPay is a new way for patients to pay for t...
# 11   SLIC games LLC is new company focused on devel...
# 16   KnowRe is an edtech company that develops adap...
# 17   Megaphone develops massively multiplayer inter...
# 18   Mobile Security Specialist! Real Geek?s SEWORK...
# 19   TVU Networks presents the only cross-platform ...
# 20   Playnery, Inc. is a top-tier development studi...
# 21   Our mission is to continue producing engaging,...
# 28   Argyle Data (formerly uCirrus) provides a big ...
# 32   Chartboost is the world?s largest games-only t...
# 33   Sim Ops Studios, Inc., a spin-off from Carnegi...
# 31   Sequent Software provides a leading Near Field...
# 29   Cue (formerly Greplin) is a free service that ...
# 27   Kabam is the leader in the western world for f...
# 24   Mytopia is a place for playing social games wi...
# 25   Is an end to end solution that supports creato...
# 26   Giiv is a text message gifting platform that a...
# 23   RockYouÂ® is committed to defining the future ...
# ..                                                 ...
# 108             LaunchBit is an ad platform for email.
# 107  AdGrok allows business owners to automate the ...
# 106  Nvidia specializes in the manufacture of graph...
# 105  What could you build if you had dead-simple ac...
# 104  Facebook is the world's largest social network...
# 103  Kaiam is a private company commercializing pho...
# 102  ZipZap, Inc. is a global cash transaction netw...
# 101  Gaikai (Gaikai Inc.) is a next generation vide...
# 100  Harvest enables communities to produce renewab...
# 99   Compass Labs provides a self-service or fully ...
# 98   Kno, Inc. is an education software company on ...
# 97   Heyday?s mission is to help you remember the s...
# 96   Jelli is 100% user-controlled radio, enabling ...
# 95   Virdia, formerly HCL CleanTech, a leading deve...
# 94   [Tivo](http://www.tivo.com) is a brand of digi...
# 92   One Kings Lane is the leading flash sales site...
# 91   Citrix specializes in application delivery inf...
# 90   Emu is a messaging app for Android with a buil...
# 89   StreamOnce transforms how teams collaborate by...
# 88   Enigma, a New York City-based developer of sol...
# 87   Quick Hit is a leading developer and publisher...
# 86   Playnomics, a predictive data and marketing pl...
# 85   Headquartered in [New York](/maps/city/New%252...
# 84   Omada Health (http://omadahealth.com) is a new...
# 83   Euclid delivers actionable shopper insights to...
# 82   Chegg, an online textbook rental company, was ...
# 43   Rumble Entertainment was founded in 2011 with ...
# 109  Aquion Energy is producing a revolutionary bat...
# 93   I needed to draft you a ltilte observation jus...
# 110  Surf Air is starting an all-you-can-fly member...
#
# [111 rows x 18 columns]
